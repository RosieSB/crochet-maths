# %%
R_widget = widget.FloatSlider(min=0.0, max=10.0, step=0.05)
R = FloatSlider(min=0.5, max=10.0, step=0.05, value=5.0)

def update_R(*args):
    R = R_widget
R_widget.observe(update_R, 'value')

def printer(R_widget, R):
    print(R_widget, R)
interact(printer,x=R_widget, y=R);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 R_widget = FloatSlider(min=0.0, max=10.0, step=0.05)
#       2 R = FloatSlider(min=0.5, max=10.0, step=0.05, value=5.0)
#       4 def update_R(*args):
#
# NameError: name 'FloatSlider' is not defined
