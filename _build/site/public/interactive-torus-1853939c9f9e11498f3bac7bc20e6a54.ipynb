# %%
import ipywidgets as widgets
from ipywidgets import HBox, VBox
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display

@widgets.interact_manual(R=4.,r=1.78,w=.4,h=.4)
def update_values(R,r,w,h):
    return (R,r,w,
# Out:
# interactive(children=(FloatSlider(value=1.0, description='freq', max=3.0, min=-1.0), Text(value='blue', contin…
