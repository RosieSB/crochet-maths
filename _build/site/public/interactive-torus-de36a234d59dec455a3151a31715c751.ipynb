# %%
#| label: R_value
import ipywidgets as widget
from ipywidgets import interact, interactive, fixed, interact_manual
import numpy as np
from IPython.display import display

R_slide = widget.FloatSlider(min=0, max=10, step=.01, value=4, description='R_slide')

def f(R_slide):
    R = R_slide.value
    print(R)

interact(f)

R_slide
print(R)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 13
#      10     R = R_slide.value
#      11     print(R)
# ---> 13 interact(f)
#      15 R_slide
#      16 print(R)
#
# File ~/MPS002/MPS002(1)/.venv/lib/python3.13/site-packages/ipywidgets/widgets/interaction.py:536, in _InteractFactory.__call__(self, _InteractFactory__interact_f, **kwargs)
#     528     return self
#     530 # positional arg support in: https://gist.github.com/8851331
#     531 # Handle the cases 1 and 2
#     532 # 1. interact(f, **kwargs)
#     533 # 2. @interact
#     534 #    def f(*args, **kwargs):
#     535 #        ...
# --> 536 w = self.widget(f)
#     537 try:
#     538     f.widget = w
#
# File ~/MPS002/MPS002(1)/.venv/lib/python3.13/site-packages/ipywidgets/widgets/interaction.py:452, in _InteractFactory.widget(self, f)
#     436 def widget(self, f):
#     437     """
#     438     Return an interactive function widget for the given function.
#     439
#    (...)    450         The function to which the interactive widgets are tied.
#     451     """
# --> 452     return self.cls(f, self.opts, **self.kwargs)
#
# File ~/MPS002/MPS002(1)/.venv/lib/python3.13/site-packages/ipywidgets/widgets/interaction.py:175, in interactive.__init__(self, _interactive__interact_f, _interactive__options, **kwargs)
#     172 self.manual_name = __options.get("manual_name", "Run Interact")
#     173 self.auto_display = __options.get("auto_display", False)
# --> 175 new_kwargs = self.find_abbreviations(kwargs)
#     176 # Before we proceed, let's make sure that the user has passed a set of args+kwargs
#     177 # that will lead to a valid call of the function. This protects against unspecified
#     178 # and doubly-specified arguments.
#     179 try:
#
# File ~/MPS002/MPS002(1)/.venv/lib/python3.13/site-packages/ipywidgets/widgets/interaction.py:275, in interactive.find_abbreviations(self, kwargs)
#     273     for name, value, default in _yield_abbreviations_for_parameter(param, kwargs):
#     274         if value is empty:
# --> 275             raise ValueError('cannot find widget or abbreviation for argument: {!r}'.format(name))
#     276         new_kwargs.append((name, value, default))
#     277 return new_kwargs
#
# ValueError: cannot find widget or abbreviation for argument: 'R_slide'

# %%
#| label: r_value

r_slide = widget.FloatSlider(min=0, max=10, step=.01, value=1.78, description='r')
r = r_slide.value
r_slide

# %%
#| label: w_value

w_slide = widget.FloatSlider(min=0, max=2, step=.01, value=.4, description='w')
w = w_slide.value
w_slide

# %%
#| label: h_value

h_slide = widget.FloatSlider(min=0, max=2, step=.01, value=.4, description='h')
h = h_slide.value
h_slide

# %%
#| label: N_value

N = round(r*np.pi/h)

# %%
#| label: Stitch_count
st_count = [0]*(N+1)
row = [0]*(N+1)
for n in range(N+1):
    theta = n*np.pi/N
    st_count[n] = str(round(2*np.pi*(R-r*np.cos(theta))/w))
    row[n] = n

# %% [markdown]
# Parameters: major radius R = {eval}`R`; minor radius r = {eval}`r`; stitch height h = {eval}`h`; stitch width w = {eval}`w`.
#
# Number of rows: $N = \lfloor\frac{r\pi}{h}\rfloor = ${eval}`N`.
#
# **Row 0.** Chain {eval}`st_count[0]` and join into round. 1 st into each chain sp around.
#
# **Subsequent rows:** Work the following stitch counts in subsequent rows. Increases made using 2 st in st of previous row. Try to evenly distribute increases for a symmetrical look.

# %%
from tabulate import tabulate
import numpy as np

table = np.transpose([row, st_count])
pattern = tabulate(table,headers=["Row","Stitch count"],tablefmt="plain")
print(pattern)
