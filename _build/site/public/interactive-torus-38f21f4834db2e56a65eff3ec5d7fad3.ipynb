# %%
#| label: R_value
import ipywidgets as widge
from ipywidgets import HBox, VBox
import numpy as np
from IPython.display import display

R_slide = widget.FloatSlider(min=0, max=10, step=.01, value=4,description='R')
R=R_slide.value
R_slide
# Out:
# FloatSlider(value=4.0, description='R', max=10.0, step=0.01)

# %%
print(R)
# Out:
# 4.0
